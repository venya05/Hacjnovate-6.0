# %% [markdown]
# <a href="https://colab.research.google.com/github/venya05/Hacknovate-6.0/blob/main/final__newtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gradio as gr
import base64

# Function to encode images to base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return f"data:image/jpeg;base64,{base64.b64encode(image_file.read()).decode()}"

# Paths to local images
image_path_home = "/content/drive/MyDrive/home intro.jpg"
image_path_test = "/content/drive/MyDrive/take_a_test.jpg"
image_path_therapy = "/content/drive/MyDrive/online_therapy_img.jpg"
image_path_autism = "/content/drive/MyDrive/ask_person_thinking.jpg"
image_path_contact = "/content/drive/MyDrive/contact_us.jpg"
image_path_extra = "/content/drive/MyDrive/test2.jpg"

# Convert images to base64
image_home_base64 = encode_image(image_path_home)
image_test_base64 = encode_image(image_path_test)
image_therapy_base64 = encode_image(image_path_therapy)
image_autism_base64 = encode_image(image_path_autism)
image_contact_base64 = encode_image(image_path_contact)
image_extra_base64 = encode_image(image_path_extra)

def home():
    return f"""<div style='background-color: #9FAC9D; padding: 20px; border-radius: 10px;'>
                <div style='display: flex; align-items: center;'>
                    <img src='{image_home_base64}' style='width: 40%; border-radius: 10px;'>
                    <div style='padding-left: 20px;'>
                        <h1 style='color: #2A363B; font-size: 48px;'>One Scan at a Time</h1>
                        <p style='font-size: 20px;'>Autism Care is dedicated to early detection and support for individuals on the autism spectrum.
                        Using MRI-based analysis and AI-driven insights, we provide accurate autism detection, personalized therapy,
                        and medical report evaluation.</p>
                    </div>
                </div>
            </div>"""

def take_test():
     return f"""
    <div style="
        background-image: url('file_path_placeholder.jpg');
        background-size: cover;
        background-position: center;
        padding: 20px;
        border-radius: 10px;
    ">
        <div style='background-color:#89999A; padding: 20px; border-radius: 10px;'>
            <div style='display: flex; align-items: center;'>
                <img src='{image_test_base64}' style='width: 40%; border-radius: 10px;'>
                <div style='padding-left: 20px;'>
                    <h2 style='font-size: 36px;'>Take a Test – MRI-Based Autism Detection</h2>
                    <p style='font-size: 20px;'>Upload your structural MRI scan and let our AI-powered system analyze it for autism detection.</p>
                    <h3 style='font-size: 28px;'> How It Works?</h3>
                    <ul style='font-size: 20px;'>
                        <li>Upload your Structural MRI scan.</li>
                        <li>Our AI processes the scan and analyzes key neurological markers.</li>
                        <li>Receive a detailed report indicating the likelihood of autism.</li>
                    </ul>
                </div>
            </div>
            <div style='display: flex; align-items: center; margin-top: 20px;'>
                <div style='flex: 1; padding-right: 20px;'>
                    <h3 style='font-size: 28px;'> Additional Information</h3>
                    <ul style='font-size: 20px;'>
                        <li> Advanced AI-driven analytics.</li>
                       <li> Bringing intelligence to healthcare in a new way.<li>
                    </ul>
                </div>
                <img src='{image_extra_base64}' style='width: 40%; border-radius: 10px;'>
            </div>
        </div>
    </div>
    """

def online_therapy():
    return f"""
    <div style='background-color: #ECE4D7; padding: 20px; border-radius: 10px;'>
        <div style='display: flex; align-items: center;'>
            <img src='{image_therapy_base64}' style='width: 40%; border-radius: 10px;'>
            <div style='padding-left: 20px;'>
                <h2 style='font-size: 36px;'>Online Therapy – Support When You Need It</h2>
                <p style='font-size: 20px;'>Living with autism comes with unique challenges. Our online therapy sessions are here to support you.</p>
                <ul style='font-size: 20px;'>
                    <li>🌿 One-on-one virtual sessions designed for your comfort</li>
                    <li>🧩 A safe, judgment-free space to express yourself</li>
                </ul>
            </div>
        </div>
        <iframe
            src="https://agent.ai/agent/u3dd5r0epvfy3kdl"
            width="100%"
            height="600px"
            style="border:none; border-radius:10px; box-shadow:0 2px 8px rgba(0,0,0,0.1);">
        </iframe>
    </div>
    """

def ask_about_autism():
    return f"""<div style='background-color: #DDC8B7; padding: 20px; border-radius: 10px;'>
                <div style='display: flex; align-items: center;'>
                    <img src='{image_autism_base64}' style='width: 40%; border-radius: 10px;'>
                    <div style='padding-left: 20px;'>
                        <h2 style='font-size: 36px;'>Ask About Autism</h2>
                        <p style='font-size: 20px;'>Have questions about autism? We’re here to help.</p>
                        <ul style='font-size: 20px;'>
                            <li>🧩 Understand autism better</li>
                            <li>💙 Get insights</li>
                            <li>💬 Ask without hesitation</li>
                        </ul>
                    </div>
                </div>
            </div>"""

def contact_us():
    return f"""<div style='background-color: #CDACA1; padding: 20px; border-radius: 10px;'>
                <div style='display: flex; align-items: center;'>
                    <img src='{image_contact_base64}' style='width: 40%; border-radius: 10px;'>
                    <div style='padding-left: 20px;'>
                        <h2 style='font-size: 36px;'>Contact Us</h2>
                        <p style='font-size: 20px;'>Reach out to us for support and inquiries.</p>
                        <p style='font-size: 20px;'>📧 Email: autismcare@gmail.com</p>
                        <p style='font-size: 20px;'>📞 Toll-Free: 1800-123-4567</p>
                    </div>
                </div>
            </div>"""
import gradio as gr
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

WEBHOOK_URL = "https://api-lr.agent.ai/v1/agent/lhpghuo43l2i5e21/webhook/070c8d44"

questions = [
    ("Do loud noises or bright lights overwhelm you?", ["Yes", "No", "Sometimes"]),
    ("Are there textures (e.g., clothing, food) or smells you avoid?", ["Yes", "No"]),
    ("Do you use tools like noise-canceling headphones or sunglasses to cope?", ["Yes", "No"]),
    ("Do you prefer using gestures, writing, or visuals over speaking?", ["Yes", "No"]),
    ("Do social interactions feel draining or confusing?", ["Yes", "No", "Sometimes"]),
    ("Do you struggle to recognize sarcasm or figurative language?", ["Yes", "No"]),
    ("Are group settings harder for you than one-on-one conversations?", ["Yes", "No"]),
    ("Do unexpected changes in plans cause stress?", ["Yes", "No", "Sometimes"]),
    ("Do you rely on a strict daily schedule to feel calm?", ["Yes", "No"]),
    ("Are transitions between activities challenging?", ["Yes", "No", "Sometimes"]),
    ("Do you stim (e.g., rocking, fidgeting) to manage emotions?", ["Yes", "No"]),
    ("Do you experience meltdowns or shutdowns when overwhelmed?", ["Yes", "No", "Sometimes"]),
    ("Have mindfulness or breathing exercises helped you calm down?", ["Yes", "No"]),
    ("Do you have intense interests or hobbies that bring you joy?", ["Yes", "No"]),
    ("Are there activities where you feel most focused or confident?", ["Yes", "No"]),
    ("Do you need support with tasks like cooking, cleaning, or time management?", ["Yes", "No"]),
    ("Are visual aids (e.g., schedules, checklists) helpful for daily routines?", ["Yes", "No"]),
    ("Have you tried therapies like occupational therapy (OT) or CBT?", ["Yes", "No"]),
    ("Would you like help improving communication or social skills?", ["Yes", "No"]),
    ("Do you prefer therapy that incorporates your interests (e.g., art, technology)?", ["Yes", "No"])
]

param_mapping = [
    "a", "social_score", "b", "c", "d", "e", "f", "g",
    "h", "i", "s", "j", "k", "l", "m", "n", "o", "p", "t", "q"
]

def create_session():
    session = requests.Session()
    retries = Retry(total=3, backoff_factor=1, status_forcelist=[500, 502, 503, 504])
    session.mount('https://', HTTPAdapter(max_retries=retries))
    return session

def get_agent_response(*answers):
    payload = {param: answer.lower() for param, answer in zip(param_mapping, answers) if answer is not None}
    try:
        with create_session() as session:
            response = session.post(WEBHOOK_URL, json=payload, timeout=20)
            if response.status_code == 200:
                return response.json().get("response", "Thank you. We've received your input.")
            else:
                return "Something went wrong. Please try again."
    except Exception as e:
        return f"Error: {str(e)}"

therapy_inputs = [gr.Radio(choices, label=question) for question, choices in questions]
therapy_interface = gr.Interface(
    fn=get_agent_response,
    inputs=therapy_inputs,
    outputs="text",
    title="Autism Care – Therapy Preference Questionnaire",
    description="Answer the following questions to personalize your therapy suggestions."
)

with gr.Blocks(css="""
    body { background-color: #89999A; color: #2A363B; font-family: Arial, sans-serif; }
    .gradio-container { padding: 20px; }
    h1 { font-size: 48px !important; }
    h2 { font-size: 36px !important; }
    h3 { font-size: 28px !important; }
    p, li { font-size: 20px !important; }
""") as demo:
    gr.Markdown("""<h1 style='text-align: left; color: #2A363B;'>Autism Care</h1>""")
    with gr.Tabs():
        with gr.Tab("Home"):
            gr.Markdown(home())
            gr.Markdown(take_test())
            gr.Markdown(online_therapy())
            gr.Markdown(ask_about_autism())


        with gr.Tab("Take a Test"):
            iface.render()

        with gr.Tab("Online Therapy"):
            gr.Markdown(online_therapy())
            therapy_interface.render()

        with gr.Tab("Ask Anything About Autism"):
            ask_about_autism_chatbot()
        with gr.Tab("Contact Us"):
            gr.Markdown(contact_us())

demo.launch()
# Out:
# <ipython-input-17-2e2190724375>:45: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=500, show_copy_button=True)
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ecd527ed8e9caf8191.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...

# %%
import gradio as gr
import tensorflow as tf
import nibabel as nib
import cv2
import numpy as np
import os

# Load the trained model
model = tf.keras.models.load_model("/content/drive/MyDrive/autismdetct.keras")

def preprocess_image(nii_path, target_size=224):
    """Preprocess MRI image to match training pipeline"""
    try:
        # Load the .nii image
        nii_img = nib.load(nii_path)
        img_data = nii_img.get_fdata()

        # Select a central slice
        slice_2d = img_data[:, :, img_data.shape[2] // 2]

        # Resize to target size
        resized_slice = cv2.resize(slice_2d, (target_size, target_size))

        # Normalize and apply Gaussian smoothing
        normalized_slice = cv2.normalize(resized_slice, None, 0, 255, cv2.NORM_MINMAX)
        blurred_slice = cv2.GaussianBlur(normalized_slice, (5, 5), 0)

        # Reshape and add channel dimension
        processed_image = blurred_slice.reshape(target_size, target_size, 1)

        # Scale to [0,1] range
        processed_image = processed_image.astype('float32') / 255.0

        return processed_image
    except Exception as e:
        raise ValueError(f"Image processing failed: {str(e)}")

def extract_features(image):
    """Extract features using VGG16 architecture with correct output shape"""
    # Initialize VGG16 model for feature extraction
    vgg_base = tf.keras.applications.VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )

    # Adapt for single-channel input by repeating the channel 3 times
    if len(image.shape) == 3:
        image = np.expand_dims(image, axis=0)  # Add batch dimension

    # Convert grayscale to "RGB" by repeating the channel
    rgb_image = np.repeat(image, 3, axis=-1)

    # Extract features (output shape will be (1, 7, 7, 512))
    features = vgg_base.predict(rgb_image)
    return features

def predict_autism(uploaded_file_path):
    try:
        # Check file exists and is .nii
        if not os.path.exists(uploaded_file_path):
            return "❌ ERROR: File not found after upload."
        if not uploaded_file_path.lower().endswith(".nii"):
            return "❌ ERROR: Please upload a .nii file"

        # Process the image
        processed_image = preprocess_image(uploaded_file_path)

        # Extract features (shape will be (1, 7, 7, 512))
        features = extract_features(processed_image)

        # DON'T FLATTEN - your model expects (None, 7, 7, 512) shape
        # Just pass the features directly
        prediction = model.predict(features)
        confidence = prediction[0][0]
        result = "Autistic" if confidence > 0.5 else "Not Autistic"
        return f"✅ Prediction: {result}"

    except nib.filebasedimages.ImageFileError:
        return "❌ ERROR: Invalid NIfTI file. Please upload a valid .nii file."
    except Exception as e:
        return f"❌ ERROR: {str(e)}"

# Gradio Interface
iface = gr.Interface(
    fn=predict_autism,
    inputs=gr.File(type="filepath", label="Upload MRI Scan (.nii)"),
    outputs="text",
    title="Autism Detection from MRI",
    description="Upload an MRI scan in .nii format to check for autism.",
    allow_flagging="never"
)

iface.launch(debug=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.11/dist-packages/gradio/interface.py:415: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://81f32cf67f0394a080.gradio.live
#
# ...

# %%
import gradio as gr
import openai
import time
from typing import List, Tuple

# Configuration
client = openai.OpenAI(
    api_key="sk-DkstlbTPsZLDJtAV3862FA",
    base_url="https://chatapi.akash.network/api/v1"
)

MODEL_NAME = "Meta-Llama-3-1-8B-Instruct-FP8"

def query_akash_llm(prompt: str, history: List[Tuple[str, str]]) -> str:
    """Query Akash Network's LLM with proper message formatting"""
    try:
        messages = []
        for user_msg, bot_msg in history:
            messages.append({"role": "user", "content": user_msg})
            if bot_msg:
                messages.append({"role": "assistant", "content": bot_msg})
        messages.append({"role": "user", "content": prompt})

        response = client.chat.completions.create(
            model=MODEL_NAME,
            messages=messages,
            temperature=0.7,
            max_tokens=500
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

def chat_interface(message, history):
    """Chat interface with input clearing"""
    response = query_akash_llm(message, history)
    history.append((message, response))

    # Clear input after processing
    yield history, ""

def ask_about_autism_chatbot():
    with gr.Column():
        gr.Markdown("### 🧠 Autism & Mental Health Support")
        chatbot = gr.Chatbot(height=500, show_copy_button=True)
        msg = gr.Textbox(
            label="Your Question",
            placeholder="Ask about autism or mental health...",
            show_label=False
        )

        with gr.Row():
            submit = gr.Button("Send", variant="primary")
            clear = gr.Button("Clear")

        msg.submit(
            chat_interface,
            [msg, chatbot],
            [chatbot, msg]
        )

        submit.click(
            chat_interface,
            [msg, chatbot],
            [chatbot, msg]
        )

        clear.click(lambda: None, None, chatbot)



if __name__ == "__main__":

    demo.launch()
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ecd527ed8e9caf8191.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ecd527ed8e9caf8191.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

WEBHOOK_URL = "https://api-lr.agent.ai/v1/agent/lhpghuo43l2i5e21/webhook/070c8d44"

questions = [
    ("Do loud noises or bright lights overwhelm you?", ["Yes", "No", "Sometimes"]),
    ("Are there textures (e.g., clothing, food) or smells you avoid?", ["Yes", "No"]),
    ("Do you use tools like noise-canceling headphones or sunglasses to cope?", ["Yes", "No"]),
    ("Do you prefer using gestures, writing, or visuals over speaking?", ["Yes", "No"]),
    ("Do social interactions feel draining or confusing?", ["Yes", "No", "Sometimes"]),
    ("Do you struggle to recognize sarcasm or figurative language?", ["Yes", "No"]),
    ("Are group settings harder for you than one-on-one conversations?", ["Yes", "No"]),
    ("Do unexpected changes in plans cause stress?", ["Yes", "No", "Sometimes"]),
    ("Do you rely on a strict daily schedule to feel calm?", ["Yes", "No"]),
    ("Are transitions between activities challenging?", ["Yes", "No", "Sometimes"]),
    ("Do you stim (e.g., rocking, fidgeting) to manage emotions?", ["Yes", "No"]),
    ("Do you experience meltdowns or shutdowns when overwhelmed?", ["Yes", "No", "Sometimes"]),
    ("Have mindfulness or breathing exercises helped you calm down?", ["Yes", "No"]),
    ("Do you have intense interests or hobbies that bring you joy?", ["Yes", "No"]),
    ("Are there activities where you feel most focused or confident?", ["Yes", "No"]),
    ("Do you need support with tasks like cooking, cleaning, or time management?", ["Yes", "No"]),
    ("Are visual aids (e.g., schedules, checklists) helpful for daily routines?", ["Yes", "No"]),
    ("Have you tried therapies like occupational therapy (OT) or CBT?", ["Yes", "No"]),
    ("Would you like help improving communication or social skills?", ["Yes", "No"]),
    ("Do you prefer therapy that incorporates your interests (e.g., art, technology)?", ["Yes", "No"])
]

param_mapping = [
    "a", "social_score", "b", "c", "d", "e", "f", "g",
    "h", "i", "s", "j", "k", "l", "m", "n", "o", "p", "t", "q"
]

def create_session():
    session = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[500, 502, 503, 504]
    )
    session.mount('https://', HTTPAdapter(max_retries=retries))
    return session

def get_agent_response(*answers):
    payload = {
        param: answer.lower()
        for param, answer in zip(param_mapping, answers)
        if answer is not None
    }

    try:
        with create_session() as session:
            response = session.post(
                WEBHOOK_URL,
                json=payload,
                timeout=20
            )
            if response.status_code == 200:
                return response.json().get("response", "No response received from agent")
            return f"Error {response.status_code}: Server issue"
    except requests.Timeout:
        return "Request timed out. Please try again."
    except Exception as e:
        return f"Connection error: {str(e)}"

custom_css = """
body {
    font-family: Arial, sans-serif;
    background-color: #ECE4D7;
    color: #4d5659;
}

.gradio-container {
    background-color: white;
}

#questions-column {
    padding: 20px;
    background: #CDACA1;
    border-radius: 20px;
    box-shadow: 0 4px 12px rgba(236, 228, 215, 0.2);
    color: #4d5659;
}

#therapy-column {
    padding: 20px;
    background: #9FAC9D;
    border-radius: 20px;
    box-shadow: 0 4px 12px rgba(236, 228, 215, 0.2);
    color: #4d5659;
}

.question-item {
    margin-bottom: 16px;
}

.therapy-box {
    padding: 16px;
    background: #ECE4D7;
    border: 1px solid #CDACA1;
    border-radius: 15px;
    font-size: 16px;
    color: #4d5659;
}

#plan-output {
    font-weight: 500;
    color: #4d5659;
    line-height: 1.6;
}

button.submit-btn {
    background-color: #89999A !important;
    color: white !important;
    border-radius: 12px;
    padding: 10px 20px;
    font-weight: bold;
    transition: background 0.3s ease;
}

button.submit-btn:hover {
    background-color: #4d5659 !important;
    color: white !important;
}

button {
    border-radius: 10px;
    font-weight: 500;
    padding: 10px 18px;
    background-color: #CDACA1;
    color: #4d5659;
    border: none;
}

button:hover {
    background-color: #9FAC9D;
    color: white;
}

/* Override question label color */
label, .gr-radio label {
    color: #4d5659 !important;
    font-weight: 500;
}

/* Custom colored radio buttons */
.radio-colored .gr-radio label:nth-child(1) {
    background-color: #CDACA1;
    color: #4d5659;
    border-radius: 10px;
    padding: 6px 12px;
    margin: 4px;
}

.radio-colored .gr-radio label:nth-child(2) {
    background-color: #9FAC9D;
    color: #4d5659;
    border-radius: 10px;
    padding: 6px 12px;
    margin: 4px;
}

.radio-colored .gr-radio label:nth-child(3) {
    background-color: #ECE4D7;
    color: #4d5659;
    border-radius: 10px;
    padding: 6px 12px;
    margin: 4px;
}

/* Selected option highlight */
.radio-colored .gr-radio input[type="radio"]:checked + label {
    border: 2px solid #4d5659;
    font-weight: bold;
}

.gradio-container label {
    color: #4d5659 !important;
    font-size: 17px;
    font-weight: 600;
}

"""

def validate_answers(*answers):
    return all(answer is not None and answer != "" for answer in answers)

with gr.Blocks(theme=gr.themes.Soft(), css=custom_css) as app:
    gr.Markdown("## Neurodiversity Assessment Questionnaire")

    with gr.Row():
        with gr.Column(elem_id="questions-column"):
            inputs = []
            for idx, (q_text, options) in enumerate(questions, 1):
                with gr.Group(elem_classes="question-item"):
                    radio = gr.Radio(
                        options,
                        label=f"{idx}. {q_text}",
                        interactive=True,
                        elem_classes="radio-colored"
                    )
                    inputs.append(radio)

        with gr.Column(elem_id="therapy-column"):
            with gr.Group(elem_classes="therapy-box"):
                output = gr.Markdown(
                    value="*Complete all questions to generate your therapy plan*",
                    elem_id="plan-output"
                )

    with gr.Row():
        clear_btn = gr.Button("Clear All Answers")
        submit_btn = gr.Button(
            "Generate Therapy Plan",
            variant="primary",
            interactive=False,
            elem_classes="submit-btn"
        )

    def on_radio_change(*answers):
        return gr.Button(interactive=all(a is not None and a != "" for a in answers))

    for radio in inputs:
        radio.change(
            fn=on_radio_change,
            inputs=inputs,
            outputs=submit_btn
        )

    submit_btn.click(
        fn=lambda *a: f"**Your Personalized Therapy Plan**\n\n{get_agent_response(*a)}",
        inputs=inputs,
        outputs=output
    )

    clear_btn.click(
        fn=lambda: [None] * len(inputs) + ["*Complete all questions to generate your therapy plan*"],
        outputs=inputs + [output]
    )

app.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9be9206298819bc570.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9be9206298819bc570.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
